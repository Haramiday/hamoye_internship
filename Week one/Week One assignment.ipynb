# %%
import pandas as pd

# %%
#PART ONE
#loading all datas
cell = pd.read_csv('cell_phones.csv')
population = pd.read_csv('population1.csv')
geo = pd.read_csv('ddf--entities--geo--country.csv')

# %%
#PART TWO
merged_data = pd.merge(cell,population,on=['Country','year'])

# %%
geo.rename(columns = {'country':'geo','name':'Country'}, inplace=True)

# %%
geo.head()
# Out:
#     geo g77_and_oecd_countries income_3groups        income_groups  \
# 0  abkh                 others            NaN                  NaN
# 1   abw                 others    high_income          high_income
# 2   afg                    g77     low_income           low_income
# 3   ago                    g77  middle_income  lower_middle_income
# 4   aia                 others            NaN                  NaN
#
#    is--country iso3166_1_alpha2 iso3166_1_alpha3  iso3166_1_numeric iso3166_2  \
# 0         True              NaN              NaN                NaN       NaN
# 1         True               AW              ABW              533.0       NaN
# 2         True               AF              AFG                4.0       NaN
# 3         True               AO              AGO               24.0       NaN
# 4         True               AI              AIA              660.0       NaN
#
#    landlocked         ...           longitude  main_religion_2008  \
# ...

# %%
data = {
    'geo':geo['geo'],
    'Country' : geo['Country']
}


data_df = pd.DataFrame(data)

# %%
merged_data = pd.merge(merged_data,data_df)

# %%
merged_data
# Out:
#            Country  year  cell_phones_total  population  geo
# 0      Afghanistan  1960                0.0     9000000  afg
# 1      Afghanistan  1961                0.0     9170000  afg
# 2      Afghanistan  1962                0.0     9350000  afg
# 3      Afghanistan  1963                0.0     9540000  afg
# 4      Afghanistan  1964                0.0     9740000  afg
# 5      Afghanistan  1965                0.0     9960000  afg
# 6      Afghanistan  1966                0.0    10200000  afg
# 7      Afghanistan  1967                0.0    10400000  afg
# 8      Afghanistan  1968                0.0    10600000  afg
# 9      Afghanistan  1969                0.0    10900000  afg
# 10     Afghanistan  1970                0.0    11200000  afg
# 11     Afghanistan  1971                0.0    11500000  afg
# 12     Afghanistan  1972                0.0    11800000  afg
# 13     Afghanistan  1973                0.0    12100000  afg
# ...

# %%
#PART THREE
merged_data['cell_phone per person'] = merged_data['cell_phones_total']/merged_data['population']

# %%
merged_data
# Out:
#            Country  year  cell_phones_total  population  geo  \
# 0      Afghanistan  1960                0.0     9000000  afg
# 1      Afghanistan  1961                0.0     9170000  afg
# 2      Afghanistan  1962                0.0     9350000  afg
# 3      Afghanistan  1963                0.0     9540000  afg
# 4      Afghanistan  1964                0.0     9740000  afg
# 5      Afghanistan  1965                0.0     9960000  afg
# 6      Afghanistan  1966                0.0    10200000  afg
# 7      Afghanistan  1967                0.0    10400000  afg
# 8      Afghanistan  1968                0.0    10600000  afg
# 9      Afghanistan  1969                0.0    10900000  afg
# 10     Afghanistan  1970                0.0    11200000  afg
# 11     Afghanistan  1971                0.0    11500000  afg
# 12     Afghanistan  1972                0.0    11800000  afg
# 13     Afghanistan  1973                0.0    12100000  afg
# ...

# %%
merged_data['geo'] = merged_data['geo'].str.upper()

# %%
merged_data
# Out:
#            Country  year  cell_phones_total  population  geo  \
# 0      Afghanistan  1960                0.0     9000000  AFG
# 1      Afghanistan  1961                0.0     9170000  AFG
# 2      Afghanistan  1962                0.0     9350000  AFG
# 3      Afghanistan  1963                0.0     9540000  AFG
# 4      Afghanistan  1964                0.0     9740000  AFG
# 5      Afghanistan  1965                0.0     9960000  AFG
# 6      Afghanistan  1966                0.0    10200000  AFG
# 7      Afghanistan  1967                0.0    10400000  AFG
# 8      Afghanistan  1968                0.0    10600000  AFG
# 9      Afghanistan  1969                0.0    10900000  AFG
# 10     Afghanistan  1970                0.0    11200000  AFG
# 11     Afghanistan  1971                0.0    11500000  AFG
# 12     Afghanistan  1972                0.0    11800000  AFG
# 13     Afghanistan  1973                0.0    12100000  AFG
# ...

# %%
#PART FOUR
merged_data.describe()
# Out:
#                year  cell_phones_total    population  cell_phone per person
# count  11640.000000       1.164000e+04  1.164000e+04           11640.000000
# mean    1989.500000       7.875722e+06  2.710307e+07               0.235536
# std       17.318846       5.572496e+07  1.086187e+08               0.433303
# min     1960.000000       0.000000e+00  4.380000e+03               0.000000
# 25%     1974.750000       0.000000e+00  1.117500e+06               0.000000
# 50%     1989.500000       0.000000e+00  5.100000e+06               0.000000
# 75%     2004.250000       5.615000e+05  1.590000e+07               0.233667
# max     2019.000000       1.730000e+09  1.430000e+09               2.126068

# %%
merged_data[merged_data['year'] == 2017]
# Out:
#                               Country  year  cell_phones_total  population  \
# 57                        Afghanistan  2017         23900000.0    36300000
# 117                           Albania  2017          3630000.0     2880000
# 177                           Algeria  2017         45800000.0    41400000
# 237                           Andorra  2017            80300.0       77000
# 297                            Angola  2017         13300000.0    29800000
# 357               Antigua and Barbuda  2017           184000.0       95400
# 417                         Argentina  2017         61900000.0    43900000
# 477                           Armenia  2017          3490000.0     2940000
# 537                         Australia  2017         26700000.0    24600000
# 597                           Austria  2017         10900000.0     8820000
# 657                        Azerbaijan  2017         10100000.0     9850000
# ...

# %%
merged_data[merged_data['year'] == 2017].sort_values(by='cell_phones_total',ascending=False).head(5)
# Out:
#              Country  year  cell_phones_total  population  geo  \
# 2157           China  2017       1.470000e+09  1420000000  CHN
# 4617           India  2017       1.170000e+09  1340000000  IND
# 4677       Indonesia  2017       4.350000e+08   265000000  IDN
# 11157  United States  2017       4.000000e+08   325000000  USA
# 8577          Russia  2017       2.270000e+08   146000000  RUS
#
#        cell_phone per person
# 2157                1.035211
# 4617                0.873134
# 4677                1.641509
# 11157               1.230769
# 8577                1.554795
